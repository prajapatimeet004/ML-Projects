# %%
import pandas as pd
data = pd.read_csv(r"C:\Users\Admin\OneDrive\Desktop\python\ML\assigment\whitewines.csv")
data
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
#dividing into dependent variable and independet variable
x = data.drop(columns = 'quality')
y = data.quality

#checking for balanced data
for col in data.columns:
    print(data[col].value_counts())
# Out:
# fixed acidity
# 6.8     308
# 6.6     290
# 6.4     280
# 6.9     241
# 6.7     236
#        ...
# 4.5       1
# 4.6       1
# 11.8      1
# 14.2      1
# 3.9       1
# Name: count, Length: 68, dtype: int64
# volatile acidity
# 0.280    263
# 0.240    253
# 0.260    240
# 0.250    231
# 0.220    229
#         ...
# 0.545      1
# 0.135      1
# 0.905      1
# 0.685      1
# 0.355      1
# Name: count, Length: 125, dtype: int64
# citric acid
# 0.30    307
# 0.28    282
# 0.32    257
# 0.34    225
# 0.29    223
#        ...
# 1.66      1
# 1.23      1
# 0.86      1
# 0.11      1
# 0.99      1
# Name: count, Length: 87, dtype: int64
# residual sugar
# 1.20     187
# 1.40     184
# 1.60     165
# 1.30     147
# 1.10     146
#         ...
# 6.75       1
# 12.75      1
# 8.55       1
# 4.35       1
# 18.40      1
# Name: count, Length: 310, dtype: int64
# chlorides
# 0.044    201
# 0.036    200
# 0.042    184
# 0.040    182
# 0.046    181
#         ...
# 0.217      1
# 0.148      1
# ...

# %%
#spliting data into training and testing 
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.30,random_state = 42)

# %%
#model building 
from sklearn.tree import DecisionTreeRegressor
DTR = DecisionTreeRegressor(random_state=42)
#model.fit(X_train, y_train)
DTR.fit(x_train,y_train)
y_pred = DTR.predict(x_test)

# %%
DTR.score(x_test,y_test)
# Out:
# 0.06838225514526419

# %%
#using cross validation
from sklearn.model_selection import cross_val_score

cross_val_score(DTR,x,y,cv=5).mean()
# Out:
# -0.4361516247787067

# %%
#using shuffle split

from sklearn.model_selection import ShuffleSplit
LOO = ShuffleSplit()
cross_val_score(DTR,x,y,cv=LOO).mean()
# Out:
# 0.09360091047477721

# %%
#leave one out is not working
